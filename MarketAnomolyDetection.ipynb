# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaosShadoww/Market-Anomaly-Detection-Project/blob/main/MarketAnomolyDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("FinancialMarketData.csv")

# %%
df
# Out:
#       Y       Data  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# ...

# %%
df.describe()
# Out:
#                  Y     XAU BGNL     ECSURPUS          BDIY          CRY  \
# count  1111.000000  1111.000000  1111.000000   1111.000000  1111.000000
# mean      0.213321   987.463744     0.036153   2259.860486   245.247670
# std       0.409837   494.623740     0.349453   2017.811888    68.278066
# min       0.000000   256.680000    -0.974000    291.000000   106.293000
# 25%       0.000000   433.740000    -0.191000    990.000000   184.705550
# 50%       0.000000  1137.800000     0.035000   1518.000000   234.560000
# 75%       0.000000  1324.825000     0.260500   2685.500000   301.539500
# max       1.000000  2006.910000     0.991000  11793.000000   467.570000
#
#                DXY          JPY          GBP          Cl1          VIX  ...  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000  ...
# mean     90.934982   106.605734     1.569661    60.708101    19.992169  ...
# std      11.379095    12.840754     0.212344    25.900813     8.642157  ...
# ...

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(12,10))

# %%
df = df.rename(columns={'Y': 'Anomaly'})
df = df.rename(columns={'Data': 'Date'})

# %%
df
# Out:
#       Anomaly       Date  XAU BGNL  ECSURPUS    BDIY       CRY      DXY  \
# 0           0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560
# 1           0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860
# 2           0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410
# 3           0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920
# 4           1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220
# ...       ...        ...       ...       ...     ...       ...      ...
# 1106        0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336
# 1107        0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297
# 1108        0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335
# 1109        0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852
# 1110        0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147
#
#          JPY     GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS  \
# ...

# %%
sns.countplot(x="Anomaly", data=df)
plt.title("Distribution of anomalies")
# Out:
# Text(0.5, 1.0, 'Distribution of anomalies')

# %%
sns.scatterplot(data=df, x="VIX", y="BDIY", hue="Anomaly")
plt.title("Demand for Resources vs Volatility Index")
# Out:
# Text(0.5, 1.0, 'Demand for Resources vs Volatility Index')

# %%
features = df.dropna()

# %%
features
# Out:
#       Anomaly       Date  XAU BGNL  ECSURPUS    BDIY       CRY      DXY  \
# 0           0  1/11/2000    283.25     0.077  1388.0  157.2600  100.560
# 1           0  1/18/2000    287.65     0.043  1405.0  165.0100  101.860
# 2           0  1/25/2000    287.15     0.135  1368.0  167.2400  102.410
# 3           0   2/1/2000    282.75     0.191  1311.0  166.8500  104.920
# 4           1   2/8/2000    298.40     0.312  1277.0  165.4300  104.220
# ...       ...        ...       ...       ...     ...       ...      ...
# 1106        0  3/23/2021   1727.96     0.339  2271.0  184.5022   92.336
# 1107        0  3/30/2021   1685.56     0.303  2103.0  184.8741   93.297
# 1108        0   4/6/2021   1743.28     0.440  2092.0  185.8393   92.335
# 1109        0  4/13/2021   1742.69     0.467  2140.0  188.1368   91.852
# 1110        0  4/20/2021   1779.72     0.492  2432.0  193.8035   91.147
#
#          JPY     GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS  \
# ...

# %%
features = features[['VIX', 'BDIY', 'DXY', 'USGG30YR', 'GT10', 'GTDEM10Y']]

# %%
features
# Out:
#         VIX    BDIY      DXY  USGG30YR   GT10  GTDEM10Y
# 0     22.50  1388.0  100.560    6.6710  6.657     5.541
# 1     21.50  1405.0  101.860    6.7470  6.748     5.644
# 2     23.02  1368.0  102.410    6.6340  6.692     5.515
# 3     23.45  1311.0  104.920    6.4230  6.619     5.459
# 4     21.25  1277.0  104.220    6.2310  6.613     5.482
# ...     ...     ...      ...       ...    ...       ...
# 1106  20.30  2271.0   92.336    2.3264  1.622    -0.343
# 1107  19.61  2103.0   93.297    2.3687  1.706    -0.288
# 1108  18.12  2092.0   92.335    2.3230  1.658    -0.317
# 1109  16.65  2140.0   91.852    2.2939  1.616    -0.293
# 1110  18.46  2432.0   91.147    2.2619  1.565    -0.263
#
# [1111 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
target = df['Anomaly']

# %%
target
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1106    0
# 1107    0
# 1108    0
# 1109    0
# 1110    0
# Name: Anomaly, Length: 1111, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.15, random_state=40)

# %%
X_train
# Out:
#         VIX    BDIY      DXY  USGG30YR   GT10  GTDEM10Y
# 345   12.19  3672.0   85.170     4.943  4.811     3.808
# 953   15.25  1052.0   89.516     3.020  2.829     0.505
# 720   13.41  1551.0   79.607     3.613  2.504     1.740
# 43    24.91  1759.0  115.610     5.894  5.866     5.238
# 379   12.14  5601.0   81.831     4.843  4.682     4.182
# ...     ...     ...      ...       ...    ...       ...
# 626   20.69  1258.0   80.805     3.024  1.969     1.881
# 1016  12.93  1446.0   96.726     2.501  1.975    -0.369
# 165   33.61  1765.0   97.910     4.644  3.583     3.819
# 7     23.37  1531.0  105.920     6.140  6.409     5.500
# 219   20.67  5044.0   87.850     4.652  3.692     3.888
#
# [944 rows x 6 columns]

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.91122533,  0.67656411, -0.49367289,  0.87683685,  1.15792437,
#         0.73243217])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle
from sklearn.ensemble import IsolationForest

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, filename):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model.__class__.__name__} Accuracy: {accuracy}")
    print(f"\nClassification Report:\n{classification_report(y_test, y_pred)}")
    print("-----------")

    with open(filename, "wb") as file:
        pickle.dump(model, file)

    print(f"Model saved as {filename}")

# %%
lr_model = LogisticRegression(random_state=40)
evaluate_and_save_model(lr_model, X_train, X_test, y_train, y_test, 'lr_model.pkl')

if_model = IsolationForest(random_state=40)
if_model.fit(X_train)
y_pred_if = if_model.predict(X_test)
y_pred_if = [1 if x == -1 else 0 for x in y_pred_if]
evaluate_and_save_model(if_model, X_train, X_test, y_train, y_test, 'if_model.pkl')
# Out:
# LogisticRegression Accuracy: 0.8922155688622755
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       135
#            1       0.79      0.59      0.68        32
#
#     accuracy                           0.89       167
#    macro avg       0.85      0.78      0.81       167
# weighted avg       0.89      0.89      0.89       167
#
# -----------
# Model saved as lr_model.pkl
# IsolationForest Accuracy: 0.05389221556886228
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         0
#            0       0.00      0.00      0.00       135
#            1       0.08      0.28      0.12        32
#
#     accuracy                           0.05       167
#    macro avg       0.03      0.09      0.04       167
# weighted avg       0.01      0.05      0.02       167
#
# -----------
# Model saved as if_model.pkl
# ...

# %%
feature_importances = lr_model.coef_[0]

importance_df = pd.DataFrame({
    'Feature': features.columns,
    'Coefficient': feature_importances
}).sort_values(by='Coefficient', ascending=False)

# %%
importance_df
# Out:
#     Feature  Coefficient
# 5  GTDEM10Y     1.889219
# 0       VIX     1.694029
# 4      GT10     0.367271
# 2       DXY    -0.137192
# 1      BDIY    -0.454736
# 3  USGG30YR    -1.906397
